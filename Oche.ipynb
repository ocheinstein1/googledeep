# %% [markdown]
# <a href="https://colab.research.google.com/github/ocheinstein1/googledeep/blob/main/Oche.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

random.seed(a=None, version=2)

# %%
def space_tokenize(text:str) -> list[str]:
  tokens = text.split(" ")
  return tokens
space_tokenize("JOy is spoiling the name of he subject")
# Out:
# ['JOy', 'is', 'spoiling', 'the', 'name', 'of', 'he', 'subject']

# %%
space_tokenize("This term, my students have been building strong maths skills through rounding, error intervals, 3D shape representations, plans and elevations, Pythagoras’ theorem in 2D, ratios, and proportion word problems, including inverse proportion and currency conversion. Clear explanations, targeted practice, and proven results. Looking for extra maths support? I offer engaging, personalised tutoring to help students succeed and grow in confidence")
# Out:
# ['This',
#  'term,',
#  'my',
#  'students',
#  'have',
#  'been',
#  'building',
#  'strong',
#  'maths',
#  'skills',
#  'through',
#  'rounding,',
#  'error',
#  'intervals,',
#  '3D',
#  'shape',
#  'representations,',
#  'plans',
#  'and',
#  'elevations,',
#  'Pythagoras’',
#  'theorem',
#  'in',
#  '2D,',
#  'ratios,',
#  'and',
#  'proportion',
#  'word',
#  'problems,',
#  'including',
#  'inverse',
#  'proportion',
#  'and',
#  'currency',
#  'conversion.',
#  'Clear',
#  'explanations,',
#  'targeted',
#  'practice,',
#  'and',
#  'proven',
#  'results.',
#  'Looking',
#  'for',
#  'extra',
#  'maths',
#  'support?',
#  'I',
#  'offer',
#  'engaging,',
#  'personalised',
#  'tutoring',
#  'to',
#  'help',
#  'students',
#  'succeed',
#  'and',
#  'grow',
#  'in',
#  'confidence']

# %% [markdown]
# learning count syntax

# %%
words = ['heat', "hate", "let", "tell", "Heat", "Heat", "Let", "Heat"]
for i in words:
  print (i)
# Out:
# heat
# hate
# let
# tell
# Heat
# Heat
# Let
# Heat

# %%
count = words.count("Heat")
print(count)
# Out:
# 3

# %%
sentence = "I am very flaggerbasted"
count=sentence.count("a")
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
from collections import Counter
words = ["ratel", "tell", "wrote", "hut", "heat", "Tunder", "ratel", "tell"]
count=Counter(words)
print(count)
# Out:
# Counter({'ratel': 2, 'tell': 2, 'wrote': 1, 'hut': 1, 'heat': 1, 'Tunder': 1})

# %%
from collections import Counter
words= ["habit", "heat", "heat"]
counts = Counter(words)
dictionary=dict(counts)
print(dictionary)
# Out:
# {'habit': 1, 'heat': 2}

# %% [markdown]
# LEARNING DICTIONARIES

# %%
dit={
    "name": "Ademola",
    "age": 56,
    "Sex": "M",
    "LOcation": "ABuja"
}
print(dit)
# Out:
# {'name': 'Ademola', 'age': 56, 'Sex': 'M', 'LOcation': 'ABuja'}

# %%
teacher={
    "name":"Madiku Bond",
    "subject":"Physics",
    "school":"LGEA",
    "years of experience":45,
    "age": 56
}
print(teacher)
# Out:
# {'name': 'Madiku Bond', 'subject': 'Physics', 'school': 'LGEA', 'years of experience': 45, 'age': 56}

# %%
print(teacher["name"])
# Out:
# Madiku Bond

# %%
print(teacher["age"])
# Out:
# 56

# %%
print(teacher['age'],teacher['school'])
# Out:
# 56 LGEA

# %%
print(teacher['name'], teacher['years of experience'], teacher["age"])
# Out:
# Madiku Bond 45 56

# %%
print(dit['name'], dit["age"], dit['LOcation'])
# Out:
# Ademola 56 ABuja

# %%
print(len(dit))
print(len(teacher))
# Out:
# 4
# 5

# %%
print(len(teacher), teacher['school'])
# Out:
# 5 LGEA

# %%
car ={
    "brand":"Hunda",
    "electric": False,
    "years": [2020, 2024, 2026],
    "colour": ["Red", "Green", "Black"],

}
print(car)
# Out:
# {'brand': 'Hunda', 'electric': False, 'years': [2020, 2024, 2026], 'colour': ['Red', 'Green', 'Black']}

# %%
print(len(car))
# Out:
# 4

# %%
print(car["electric"])
# Out:
# False

# %%
print(car['brand'], car['years'])
# Out:
# Hunda [2020, 2024, 2026]

# %%
x =car["brand"]
print(x)
# Out:
# Hunda

# %%
x = car.get('brand')
print(x)
# Out:
# Hunda

# %%
x = car.get('brand')
print(x)
# Out:
# Hunda

# %% [markdown]
# Working with ists and loops

# %%
mylist = ["head", "Leg", "tail", "ear", "hand", "eye", "mouth", "Torso", "Heel"]
print(mylist)
# Out:
# ['head', 'Leg', 'tail', 'ear', 'hand', 'eye', 'mouth', 'Torso', 'Heel']

# %%
print(mylist[0], ",", mylist[8])
# Out:
# head , Heel

# %%
print(len(mylist))
# Out:
# 9

# %%
mylist[0]="Earing"
mylist.insert(1, "Heat")
mylist.insert(5, "Goat")
print(mylist)
# Out:
# ['Earing', 'Heat', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel']

# %%
len(mylist)
# Out:
# 11

# %%
print(mylist)
mylist.remove("Heat")
# Out:
# ['Earing', 'Heat', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel']

# %%
print(mylist)
# Out:
# ['Earing', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel']

# %%
mylist.append("Heat")
print(mylist)
# Out:
# ['Earing', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel', 'Heat']

# %%
mylist.insert(0, "Temp")

# %%
print(mylist)
# Out:
# ['Temp', 'Earing', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel', 'Heat']

# %%
mylist.insert(3, "Holiday")
print(mylist)
# Out:
# ['Temp', 'Earing', 'Leg', 'Holiday', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel', 'Heat']

# %%
mylist.remove("Holiday")
print(mylist)
# Out:
# ['Temp', 'Earing', 'Leg', 'tail', 'ear', 'Goat', 'hand', 'eye', 'mouth', 'Torso', 'Heel', 'Heat']

# %%
for x in mylist:
  print(x)
# Out:
# Temp
# Earing
# Leg
# tail
# ear
# Goat
# hand
# eye
# mouth
# Torso
# Heel
# Heat

# %%
for i in mylist:
  print(i)
  if i=="Torso":
    break
# Out:
# Temp
# Earing
# Leg
# tail
# ear
# Goat
# hand
# eye
# mouth
# Torso

# %%
for i in mylist:
  print(i)
  if i == "tail":
    break
# Out:
# Temp
# Earing
# Leg
# tail

# %%
for i in mylist:
  print(i)
  if i == "Torso":
    continue
# Out:
# Temp
# Earing
# Leg
# tail
# ear
# Goat
# hand
# eye
# mouth
# Torso
# Heel
# Heat

# %%
for i in range(6):
  print (i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2,30,5):
  print(x)
# Out:
# 2
# 7
# 12
# 17
# 22
# 27

# %%
for x in range (2,90,5):
  print(x)
else:
  print("FInished!!!")
# Out:
# 2
# 7
# 12
# 17
# 22
# 27
# 32
# 37
# 42
# 47
# 52
# 57
# 62
# 67
# 72
# 77
# 82
# 87
# FInished!!!

# %%
for x in range (10):
  if x == 6: break
  print(x)
else:
  print("finished!")
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# NESTED LOOPS. I AM WINING THIS

# %%
clasis = ["gd10", "gd11", "gd12"]
name = ["phil", "fed", "Ned"]

for x in clasis:
  for y in name:
    print(x,y)
# Out:
# gd10 phil
# gd10 fed
# gd10 Ned
# gd11 phil
# gd11 fed
# gd11 Ned
# gd12 phil
# gd12 fed
# gd12 Ned

# %% [markdown]
# FUNCTIONS!

# %%
def name():
  print("my name is oche")

name()
# Out:
# my name is oche

# %%
name()
# Out:
# my name is oche

# %%
def convfah(fahrenheit):
  return(fahrenheit - 32)*5/9


convfah(-8000)
# Out:
# -4462.222222222223

# %%
def hello9ja():
  return "Hello Naija 1007"

greeting = hello9ja()
print(greeting)
# Out:
# Hello Naija 1007

# %% [markdown]
# Create a function that displays your name.

# %%
def name():
  return "My name is oche"

name()
# Out:
# 'My name is oche'

# %% [markdown]
# write a function to accept a value, call the name and welcome them

# %%
def names(identity):
  print(identity + ", You are welcome")


names("Oche")
names("Phil")
names("Joe")
# Out:
# Oche, You are welcome
# Phil, You are welcome
# Joe, You are welcome

# %%
def namess(twan, twoo):
  print("Hello " + twan + ", " + twoo)

namess("Eli", "Eliana")
# Out:
# Hello Eli, Eliana

# %%
def sumnum(num1,num2):
  return(num1+num2)

sumnum(34,2)
# Out:
# 36

# %%
sumnum(9,56)
# Out:
# 65

# %%
sumnum(9,63)
# Out:
# 72

# %%
def fname(sname="emmanuel"):
  return ("Hello", sname)

fname()
# Out:
# ('Hello', 'emmanuel')

# %%
def myliist():
  return ["goat", "hen", "cow", "pig", "hont"]

anims = myliist()
print(anims[0])
# Out:
# goat

# %%
myliist()
# Out:
# ['goat', 'hen', 'cow']

# %%
print(anims[3])
# Out:
# pig

# %%
def perdict(people):
  pass

def my_function(person):
  print("Name:", person["name"])
  print("Age:", person["age"])

my_person = {"name": "Emil", "age": 25}
my_function(my_person)
# Out:
# Name: Emil
# Age: 25

# %%
def perdict(people):
  print("Name:", people["name"])
  print("Gender:", people["gender"])

verify={"name": "Ade", "gender": "M"}
perdict(verify)
# Out:
# Name: Ade
# Gender: M

# %% [markdown]
# The function should:
#
# Access the dictionary
# Return the student's name
#
# Then:
#
# Store the returned value in a variable
# Print the variable

# %%
def student(details):
  print("Name:", details["name"] )
  print("Gender:", details["gender"])
  print("Class:", details["class"])
  print("RegNo", details["regno"])

finale=  {"name": "Ade", "gender": "M", "class": "grade 10", "regno": 23}
student(finale)
# Out:
# Name: Ade
# Gender: M
# Class: grade 10
# RegNo 23

# %%
from collections import Counter

prep = [
    "Dayo",
    "femi",
    "Ife",
    "kayode",
    "Phil",
    "Femi",
    "Tim",
    "Demi",
    "femi"
]

counts = Counter(prep)
print(counts)
# Out:
# Counter({'femi': 2, 'Dayo': 1, 'Ife': 1, 'kayode': 1, 'Phil': 1, 'Femi': 1, 'Tim': 1, 'Demi': 1})

# %%
word = "Histopholicia"
counts=Counter(word)
print(counts)
# Out:
# Counter({'i': 3, 'o': 2, 'H': 1, 's': 1, 't': 1, 'p': 1, 'h': 1, 'l': 1, 'c': 1, 'a': 1})

# %%
sentence = "In this lab, you will experiment with another type of language model known as a transformer language model. You will use the transformer model to predict the next token and generate sequences. You will then compare these predictions to the trigram model from the previous lab. This will provide you with a more in-depth understanding of the shortcomings of n-gram models and highlight why more sophisticated language models, such as transformers, are required for developing language technology"
words = sentence.split()
counts=Counter(words)
print(counts)
# Out:
# Counter({'the': 5, 'will': 4, 'language': 4, 'of': 3, 'model': 3, 'you': 2, 'with': 2, 'as': 2, 'a': 2, 'transformer': 2, 'You': 2, 'to': 2, 'and': 2, 'more': 2, 'In': 1, 'this': 1, 'lab,': 1, 'experiment': 1, 'another': 1, 'type': 1, 'known': 1, 'model.': 1, 'use': 1, 'predict': 1, 'next': 1, 'token': 1, 'generate': 1, 'sequences.': 1, 'then': 1, 'compare': 1, 'these': 1, 'predictions': 1, 'trigram': 1, 'from': 1, 'previous': 1, 'lab.': 1, 'This': 1, 'provide': 1, 'in-depth': 1, 'understanding': 1, 'shortcomings': 1, 'n-gram': 1, 'models': 1, 'highlight': 1, 'why': 1, 'sophisticated': 1, 'models,': 1, 'such': 1, 'transformers,': 1, 'are': 1, 'required': 1, 'for': 1, 'developing': 1, 'technology': 1})

# %%
article = "Physics is the branch of science that seeks to understand the fundamental principles governing matter, energy, space, and time. It explains how objects move, why forces act, how electricity powers our homes, and how light, sound, and heat interact with the world around us. From the motion of planets in the solar system to the behavior of tiny subatomic particles, physics provides a framework for understanding the universe. It plays a crucial role in technological advancement, contributing to innovations such as smartphones, medical imaging devices, satellites, renewable energy systems, and modern transportation. Physics also develops critical thinking and problem-solving skills by encouraging observation, experimentation, measurement, and logical reasoning. Students who study physics gain a deeper appreciation of natural phenomena and learn to apply mathematical concepts to real-world situations. The subject forms the foundation of many fields, including engineering, astronomy, medicine, computer science, and environmental science. As scientists continue to explore the mysteries of the cosmos and develop new technologies, physics remains at the heart of discovery and innovation. Its principles not only explain how the world works but also inspire humanity to ask questions, seek evidence, and create solutions that improve the quality of life for people across the globe."

word = article.split()
counts=Counter(word)
print(counts)
# Out:
# Counter({'the': 14, 'and': 11, 'of': 8, 'to': 7, 'how': 4, 'physics': 3, 'a': 3, 'Physics': 2, 'that': 2, 'principles': 2, 'It': 2, 'world': 2, 'in': 2, 'for': 2, 'also': 2, 'is': 1, 'branch': 1, 'science': 1, 'seeks': 1, 'understand': 1, 'fundamental': 1, 'governing': 1, 'matter,': 1, 'energy,': 1, 'space,': 1, 'time.': 1, 'explains': 1, 'objects': 1, 'move,': 1, 'why': 1, 'forces': 1, 'act,': 1, 'electricity': 1, 'powers': 1, 'our': 1, 'homes,': 1, 'light,': 1, 'sound,': 1, 'heat': 1, 'interact': 1, 'with': 1, 'around': 1, 'us.': 1, 'From': 1, 'motion': 1, 'planets': 1, 'solar': 1, 'system': 1, 'behavior': 1, 'tiny': 1, 'subatomic': 1, 'particles,': 1, 'provides': 1, 'framework': 1, 'understanding': 1, 'universe.': 1, 'plays': 1, 'crucial': 1, 'role': 1, 'technological': 1, 'advancement,': 1, 'contributing': 1, 'innovations': 1, 'such': 1, 'as': 1, 'smartphones,': 1, 'medical': 1, 'imaging': 1, 'devices,': 1, 'satellites,': 1, 'renewable': 1, 'energy': 1, 'systems,': 1, 'modern': 1
# ...

# %%
for word, number in counts.items():
  print(word, number)
# Out:
# Physics 2
# is 1
# the 14
# branch 1
# of 8
# science 1
# that 2
# seeks 1
# to 7
# understand 1
# fundamental 1
# principles 2
# governing 1
# matter, 1
# energy, 1
# space, 1
# and 11
# time. 1
# It 2
# explains 1
# how 4
# objects 1
# move, 1
# why 1
# forces 1
# act, 1
# electricity 1
# powers 1
# our 1
# homes, 1
# light, 1
# sound, 1
# heat 1
# interact 1
# with 1
# world 2
# around 1
# us. 1
# From 1
# motion 1
# planets 1
# in 2
# solar 1
# system 1
# behavior 1
# tiny 1
# subatomic 1
# particles, 1
# physics 3
# provides 1
# a 3
# framework 1
# for 2
# understanding 1
# universe. 1
# plays 1
# crucial 1
# role 1
# technological 1
# advancement, 1
# contributing 1
# innovations 1
# such 1
# as 1
# smartphones, 1
# medical 1
# imaging 1
# devices, 1
# satellites, 1
# renewable 1
# energy 1
# systems, 1
# modern 1
# transportation. 1
# also 2
# develops 1
# critical 1
# thinking 1
# problem-solving 1
# skills 1
# by 1
# encouraging 1
# observation, 1
# experimentation, 1
# ...

# %%
colours = [
    "red",
    "white",
    "red",
    "white",
    "blue",
    "blue",
    "red",
    "white",
    "red",
    "white",
    "blue",
    "blue",
    "red",
    "white",
    "red",
    "white",
    "blue",
    "blue",
    "red",
    "white"
]
counts=Counter(colours)

for colours, number in counts.items():
  print(colours, number)
# Out:
# red 7
# white 7
# blue 6

# %%
name = [
    "ada",
    "adrian",
    "ada",
    "phil",
    "musa",
    "eliana",
    "musa",
    "musa",
    "eli",
    "musa",
    "adrian"
]
counts=Counter(name)

for name, number in counts.items():
  print(name, number)
# Out:
# ada 2
# adrian 2
# phil 1
# musa 4
# eliana 1
# eli 1

# %% [markdown]
# Create a list containing:
#
# Physics
# Maths
# Physics
# Biology
# Physics
# Maths
# Chemistry
#
# Use Counter to count how many times each subject appears.

# %%
subjects =[
    "Physics",
    "Maths",
    "Physics",
    "Biology",
    "Physics",
    "Maths",
    "Chemistry"
]
counts= Counter(subjects)
print(counts)
# Out:
# Counter({'Physics': 3, 'Maths': 2, 'Biology': 1, 'Chemistry': 1})

# %% [markdown]
# Create a string containing your full name.
#
# Use Counter to count each letter.

# %%
my_name= "Oche Celestine Onjewu"
counts=Counter(my_name)
print(counts)
# Out:
# Counter({'e': 5, 'O': 2, ' ': 2, 'n': 2, 'c': 1, 'h': 1, 'C': 1, 'l': 1, 's': 1, 't': 1, 'i': 1, 'j': 1, 'w': 1, 'u': 1})

# %%
"""Create a sentence containing at least 10 words.

Split the sentence into words.

Use Counter to count the words."""
sent = "I love coding and cannot afford to waste so much time again. In this present time and age, who would like to enage in this path?"
words = sent.split()
counts = Counter(words)
print(counts)
# Out:
# Counter({'and': 2, 'to': 2, 'time': 2, 'this': 2, 'I': 1, 'love': 1, 'coding': 1, 'cannot': 1, 'afford': 1, 'waste': 1, 'so': 1, 'much': 1, 'again.': 1, 'In': 1, 'present': 1, 'age,': 1, 'who': 1, 'would': 1, 'like': 1, 'enage': 1, 'in': 1, 'path?': 1})

# %%
"""Create a list containing at least 12 student names.

Repeat some names.

Use Counter to determine how many times each student appears."""
students=[
    "phil",
    "ede",
    "model",
    "tim",
    "poloh",
    "gani",
    "dora",
    "doro",
    "phil",
    "tim",
    "tim",
    "poloh"
]
counts=Counter(students)
for students, number in counts.items():
  print(students, number)
# Out:
# phil 2
# ede 1
# model 1
# tim 3
# poloh 2
# gani 1
# dora 1
# doro 1

# %%
'''Create a dictionary called:

student_scores

Store five students and their scores.

Then create a separate list containing the student names, with some names repeated.

Use Counter on the list.

Finally, print the count for each student name.'''

student_scores={
    "Abdul": 25
    "Khayel": 23
    "Bobul": 45
    "yomi": 87
    "Ade": 90
}
